# %%
from typing import TypedDict

from langgraph.checkpoint.memory import InMemorySaver
from langgraph.graph import StateGraph,END,START
from langgraph.types import interrupt, Command


#1. 声明状态
class OverAllState(TypedDict):
    initial_state:str
    parallel_node_a_1:str
    parallel_node_a_2:str
    node_b_output:str

#2. 声明节点
def parallel_node_a_1(state:OverAllState) -> OverAllState:
    return {
        "parallel_node_a_1":"并行节点A-1的输出"
    }

def parallel_node_a_2(state:OverAllState) -> OverAllState:
    return {
        "parallel_node_a_2":"并行节点A-2的输出"
    }

def node_b(state:OverAllState) -> OverAllState:
    # interrupt("hello")
    return {
        "node_b_output":"节点B的输出"
    }

#3. 构建图
builder = StateGraph(state_schema=OverAllState)
builder.add_node("parallel_node_a_1",parallel_node_a_1)
builder.add_node("parallel_node_a_2",parallel_node_a_2)
builder.add_node("node_b",node_b)
builder.add_edge(START,"parallel_node_a_1")
builder.add_edge(START,"parallel_node_a_2")
builder.add_edge(["parallel_node_a_1","parallel_node_a_2"],"node_b")
builder.add_edge("node_b",END)

#4. 添加检查点后端
checkpointer = InMemorySaver()
graph = builder.compile(checkpointer= checkpointer)

from IPython.display import display
display(graph)

config = {"configurable":{"thread_id":"123"}}
for chunk in graph.stream(
    {"initial_state":"初始状态"},
    config=config,
    stream_mode=["debug"],
    version="v2"
    # stream_mode=["tasks"]
    # stream_mode=["checkpoints"]
):
    print(chunk)
# Out:
# {'type': 'debug', 'ns': (), 'data': {'step': -1, 'timestamp': '2026-07-13T08:45:57.714162+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': '123', 'checkpoint_id': '1f17e974-45a6-6e8d-bfff-9a8a5af8b14e'}}, 'parent_config': None, 'values': {}, 'metadata': {'source': 'input', 'step': -1, 'parents': {}}, 'next': ['__start__'], 'tasks': [{'id': '2461df65-03dd-2325-9416-0c7da05eed6f', 'name': '__start__', 'interrupts': (), 'state': None}]}}}
# {'type': 'debug', 'ns': (), 'data': {'step': 0, 'timestamp': '2026-07-13T08:45:57.714991+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': '123', 'checkpoint_id': '1f17e974-45a9-6665-8000-b516629b1486'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': '123', 'checkpoint_id': '1f17e974-45a6-6e8d-bfff-9a8a5af8b14e'}}, 'values': {'initial_state': '初始状态'}, 'metadata': {'source': 'loop', 'step': 0, 'parents': {}}, 'next': ['parallel_node_a_1', 'parallel_node_a_2'], 'tasks': [{'id': '48362deb-0962-f00e-3d5d-f13ef74adc34', 'name': 'parallel_node_a_1', 'interrupts': (), 'state': None}, {'id': '47b60462-869c-4bb8-3856-8452c85d0bf6', 'name': 'parallel_node_a_2', 'interrupts': (), 'state': None}]}}}
# {'type': 'debug', 'ns': (), 'data': {'step': 1, 'timestamp': '2026-07-13T08:45:57.715003+00:00', 'type': 'task', 'payload': {'id': '48362deb-0962-f00e-3d5d-f13ef74adc34', 'name': 'parallel_node_a_1', 'input': {'initial_state': '初始状态'}, 'triggers': ('branch:to:parallel_node_a_1',)}}}
# {'type': 'debug', 'ns': (), 'data': {'step': 1, 'timestamp': '2026-07-13T08:45:57.715006+00:00', 'type': 'task', 'payload': {'id': '47b60462-869c-4bb8-3856-8452c85d0bf6', 'name': 'parallel_node_a_2', 'input': {'initial_state': '初始状态'}, 'triggers': ('branch:to:parallel_node_a_2',)}}}
# {'type': 'debug', 'ns': (), 'data': {'step': 1, 'timestamp': '2026-07-13T08:45:57.715601+00:00', 'type': 'task_result', 'payload': {'id': '47b60462-869c-4bb8-3856-8452c85d0bf6', 'name': 'parallel_node_a_2', 'error': None, 'result': {'parallel_node_a_2': '并行节点A-2的输出'}, 'interrupts': []}}}
# {'type': 'debug', 'ns': (), 'data': {'step': 1, 'timestamp': '2026-07-13T08:45:57.715668+00:00', 'type': 'task_result', 'payload': {'id': '48362deb-0962-f00e-3d5d-f13ef74adc34', 'name': 'parallel_node_a_1', 'error': None, 'result': {'parallel_node_a_1': '并行节点A-1的输出'}, 'interrupts': []}}}
# {'type': 'debug', 'ns': (), 'data': {'step': 1, 'timestamp': '2026-07-13T08:45:57.716054+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': '123', 'checkpoint_id': '1f17e974-45ac-6e66-8001-29ad775569b6'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': '123', 'checkpoint_id': '1f17e974-45a9-6665-8000-b516629b1486'}}, 'values': {'initial_state': '初始状态', 'parallel_node_a_1': '并行节点A-1的输出', 'parallel_node_a_2': '并行节点A-2的输出'}, 'metadata': {'source': 'loop', 'step': 1, 'parents': {}}, 'next': ['node_b'], 'tasks': [{'id': '8345e129-299b-79b5-4b9c-b36c183f63c7', 'name': 'node_b', 'interrupts': (), 'state': None}]}}}
# {'type': 'debug', 'ns': (), 'data': {'step': 2, 'timestamp': '2026-07-13T08:45:57.716064+00:00', 'type': 'task', 'payload': {'id': '8345e129-299b-79b5-4b9c-b36c183f63c7', 'name': 'node_b', 'input': {'initial_state': '初始状态', 'parallel_node_a_1': '并行节点A-1的输出', 'parallel_node_a_2': '并行节点A-2的输出'}, 'triggers': ('branch:to:node_b', 'join:parallel_node_a_1+parallel_node_a_2:node_b')}}}
# {'type': 'debug', 'ns': (), 'data': {'step': 2, 'timestamp': '2026-07-13T08:45:57.716217+00:00', 'type': 'task_result', 'payload': {'id': '8345e129-299b-79b5-4b9c-b36c183f63c7', 'name': 'node_b', 'error': None, 'result': {'node_b_output': '节点B的输出'}, 'interrupts': []}}}
# {'type': 'debug', 'ns': (), 'data': {'step': 2, 'timestamp': '2026-07-13T08:45:57.716943+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': '123', 'checkpoint_id': '1f17e974-45ad-6c53-8002-0aa51318c1f4'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': '123', 'checkpoint_id': '1f17e974-45ac-6e66-8001-29ad775569b6'}}, 'values': {'initial_state': '初始状态', 'parallel_node_a_1': '并行节点A-1的输出', 'parallel_node_a_2': '并行节点A-2的输出', 'node_b_output': '节点B的输出'}, 'metadata': {'source': 'loop', 'step': 2, 'parents': {}}, 'next': [], 'tasks': []}}}

# %%
from langgraph.types import interrupt, Command
print("*" * 50 )
for chunk in graph.stream(
    Command(resume=""),
    config=config,
    stream_mode=["checkpoints"]
):
    print(chunk)
# Out:
# **************************************************
# ('checkpoints', {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': '123', 'checkpoint_id': '1f17e974-45ad-6c53-8002-0aa51318c1f4'}}, 'parent_config': {'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17e974-45ac-6e66-8001-29ad775569b6'}}, 'values': {'initial_state': '初始状态', 'parallel_node_a_1': '并行节点A-1的输出', 'parallel_node_a_2': '并行节点A-2的输出', 'node_b_output': '节点B的输出'}, 'metadata': {'source': 'loop', 'step': 2, 'parents': {}}, 'next': [], 'tasks': []})

# %%
list(graph.get_state_history(config=config))
# Out:
# [StateSnapshot(values={'initial_state': '初始状态', 'parallel_node_a_1': '并行节点A-1的输出', 'parallel_node_a_2': '并行节点A-2的输出', 'node_b_output': '节点B的输出'}, next=(), config={'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17e974-45ad-6c53-8002-0aa51318c1f4'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-07-13T08:45:57.716278+00:00', parent_config={'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17e974-45ac-6e66-8001-29ad775569b6'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'initial_state': '初始状态', 'parallel_node_a_1': '并行节点A-1的输出', 'parallel_node_a_2': '并行节点A-2的输出'}, next=('node_b',), config={'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17e974-45ac-6e66-8001-29ad775569b6'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-07-13T08:45:57.715917+00:00', parent_config={'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17e974-45a9-6665-8000-b516629b1486'}}, tasks=(PregelTask(id='8345e129-299b-79b5-4b9c-b36c183f63c7', name='node_b', path=('__pregel_pull', 'node_b'), error=None, interrupts=(), state=None, result={'node_b_output': '节点B的输出'}),), interrupts=()),
#  StateSnapshot(values={'initial_state': '初始状态'}, next=('parallel_node_a_1', 'parallel_node_a_2'), config={'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17e974-45a9-6665-8000-b516629b1486'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-07-13T08:45:57.714484+00:00', parent_config={'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17e974-45a6-6e8d-bfff-9a8a5af8b14e'}}, tasks=(PregelTask(id='48362deb-0962-f00e-3d5d-f13ef74adc34', name='parallel_node_a_1', path=('__pregel_pull', 'parallel_node_a_1'), error=None, interrupts=(), state=None, result={'parallel_node_a_1': '并行节点A-1的输出'}), PregelTask(id='47b60462-869c-4bb8-3856-8452c85d0bf6', name='parallel_node_a_2', path=('__pregel_pull', 'parallel_node_a_2'), error=None, interrupts=(), state=None, result={'parallel_node_a_2': '并行节点A-2的输出'})), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17e974-45a6-6e8d-bfff-9a8a5af8b14e'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-07-13T08:45:57.713467+00:00', parent_config=None, tasks=(PregelTask(id='2461df65-03dd-2325-9416-0c7da05eed6f', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'initial_state': '初始状态'}),), interrupts=())]
