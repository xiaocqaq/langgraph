# %%
from typing import TypedDict
from langgraph.graph import StateGraph, START, END

class OverAllState(TypedDict):
    initial_state: str
    node_a_output: str
    node_b_output: str

def node_a(state: OverAllState) -> OverAllState:
    return {
        "node_a_output": "节点A的输出"
    }

def node_b(state: OverAllState) -> OverAllState:
    return {
        "node_b_output": "节点B的输出"
    }

builder = StateGraph(state_schema=OverAllState)
builder.add_node("node_a", node_a)
builder.add_node("node_b", node_b)
builder.add_edge(START, "node_a")
builder.add_edge("node_a", "node_b")
builder.add_edge("node_b", END)

graph = builder.compile()
async for chunk in graph.astream_events(
    {"initial_state": "初始状态"},
    version="v2"
):
    print(chunk)
# Out:
# {'event': 'on_chain_start', 'data': {'input': {'initial_state': '初始状态'}}, 'name': 'LangGraph', 'tags': [], 'run_id': '019f5abb-2f8d-7b51-890d-2637aec1942e', 'metadata': {}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'initial_state': '初始状态'}}, 'name': 'node_a', 'tags': ['graph:step:1'], 'run_id': '019f5abb-2f90-72f0-9036-a5c7caa6d581', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_a', 'langgraph_triggers': ('branch:to:node_a',), 'langgraph_path': ('__pregel_pull', 'node_a'), 'langgraph_checkpoint_ns': 'node_a:abdc5233-9a88-5f2e-2e8b-4a3fed2db277'}, 'parent_ids': ['019f5abb-2f8d-7b51-890d-2637aec1942e']}
# {'event': 'on_chain_stream', 'run_id': '019f5abb-2f90-72f0-9036-a5c7caa6d581', 'name': 'node_a', 'tags': ['graph:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_a', 'langgraph_triggers': ('branch:to:node_a',), 'langgraph_path': ('__pregel_pull', 'node_a'), 'langgraph_checkpoint_ns': 'node_a:abdc5233-9a88-5f2e-2e8b-4a3fed2db277'}, 'data': {'chunk': {'node_a_output': '节点A的输出'}}, 'parent_ids': ['019f5abb-2f8d-7b51-890d-2637aec1942e']}
# {'event': 'on_chain_end', 'data': {'output': {'node_a_output': '节点A的输出'}, 'input': {'initial_state': '初始状态'}}, 'run_id': '019f5abb-2f90-72f0-9036-a5c7caa6d581', 'name': 'node_a', 'tags': ['graph:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_a', 'langgraph_triggers': ('branch:to:node_a',), 'langgraph_path': ('__pregel_pull', 'node_a'), 'langgraph_checkpoint_ns': 'node_a:abdc5233-9a88-5f2e-2e8b-4a3fed2db277'}, 'parent_ids': ['019f5abb-2f8d-7b51-890d-2637aec1942e']}
# {'event': 'on_chain_stream', 'run_id': '019f5abb-2f8d-7b51-890d-2637aec1942e', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'data': {'chunk': {'node_a': {'node_a_output': '节点A的输出'}}}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'initial_state': '初始状态', 'node_a_output': '节点A的输出'}}, 'name': 'node_b', 'tags': ['graph:step:2'], 'run_id': '019f5abb-2f91-7df2-87d2-fab71b34c2f2', 'metadata': {'langgraph_step': 2, 'langgraph_node': 'node_b', 'langgraph_triggers': ('branch:to:node_b',), 'langgraph_path': ('__pregel_pull', 'node_b'), 'langgraph_checkpoint_ns': 'node_b:57b2bd39-2e3b-2724-6a98-9e28162a8b56'}, 'parent_ids': ['019f5abb-2f8d-7b51-890d-2637aec1942e']}
# {'event': 'on_chain_stream', 'run_id': '019f5abb-2f91-7df2-87d2-fab71b34c2f2', 'name': 'node_b', 'tags': ['graph:step:2'], 'metadata': {'langgraph_step': 2, 'langgraph_node': 'node_b', 'langgraph_triggers': ('branch:to:node_b',), 'langgraph_path': ('__pregel_pull', 'node_b'), 'langgraph_checkpoint_ns': 'node_b:57b2bd39-2e3b-2724-6a98-9e28162a8b56'}, 'data': {'chunk': {'node_b_output': '节点B的输出'}}, 'parent_ids': ['019f5abb-2f8d-7b51-890d-2637aec1942e']}
# {'event': 'on_chain_end', 'data': {'output': {'node_b_output': '节点B的输出'}, 'input': {'initial_state': '初始状态', 'node_a_output': '节点A的输出'}}, 'run_id': '019f5abb-2f91-7df2-87d2-fab71b34c2f2', 'name': 'node_b', 'tags': ['graph:step:2'], 'metadata': {'langgraph_step': 2, 'langgraph_node': 'node_b', 'langgraph_triggers': ('branch:to:node_b',), 'langgraph_path': ('__pregel_pull', 'node_b'), 'langgraph_checkpoint_ns': 'node_b:57b2bd39-2e3b-2724-6a98-9e28162a8b56'}, 'parent_ids': ['019f5abb-2f8d-7b51-890d-2637aec1942e']}
# {'event': 'on_chain_stream', 'run_id': '019f5abb-2f8d-7b51-890d-2637aec1942e', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'data': {'chunk': {'node_b': {'node_b_output': '节点B的输出'}}}, 'parent_ids': []}
# {'event': 'on_chain_end', 'data': {'output': {'initial_state': '初始状态', 'node_a_output': '节点A的输出', 'node_b_output': '节点B的输出'}}, 'run_id': '019f5abb-2f8d-7b51-890d-2637aec1942e', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'parent_ids': []}
